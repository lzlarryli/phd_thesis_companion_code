# %%
# %matplotlib inline
from fenics import *
from mshr import *
import matplotlib.pyplot as plt

# %%
domain = Rectangle(Point(0, 0), Point(1, 1))
mesh = generate_mesh(domain, 20)
plt.figure(figsize=(20, 20))
plot(mesh)
plt.axis("off")
plt.savefig("2d_mesh.svg", transparent=True, bbox_inches="tight", pad_inches=0.0)

# %%
from utils import gaussian_mesh_randomizer
mesh = gaussian_mesh_randomizer(UnitCubeMesh(3, 3, 3), 0.1)
File("3D_mesh.pvd") << mesh

# %%
mesh.geometry().dim()
# Out:
# 3
